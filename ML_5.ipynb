# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

data = np.random.rand(100)
labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:50]]

def euclidean_distance(x1, x2):
    return abs(x1 - x2)

def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]
    distances.sort(key=lambda x: x[0])
    k_nearest_neighbors = distances[:k]
    k_nearest_labels = [label for _, label in k_nearest_neighbors]
    return Counter(k_nearest_labels).most_common(1)[0][0]

train_data = data[:50]
train_labels = labels
test_data = data[50:]

k_values = [1, 2, 3, 4, 5, 20, 30]

print("--- k-Nearest Neighbors Classification ---")
print("Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 50 points to be classified\n")

results = {}

for k in k_values:
    print(f"Results for k = {k}:")
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels
    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}")
    print("\n")

print("Classification complete.\n")

for k in k_values:
    classified_labels = results[k]
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]

    plt.figure(figsize=(10,8))
    plt.scatter(train_data, [0] * len(train_data),
                c=["blue" if label == "Class1" else "red" for label in train_labels], label="Training Data", marker="o")
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")

    plt.title(f"k-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 50 points to be classified
#
# Results for k = 1:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class1
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 2:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class1
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 3:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class1
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 4:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class1
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 5:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class1
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 20:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class2
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Results for k = 30:
# Point x51 (value: 0.0520) is classified as Class1
# Point x52 (value: 0.4528) is classified as Class1
# Point x53 (value: 0.9192) is classified as Class2
# Point x54 (value: 0.9034) is classified as Class2
# Point x55 (value: 0.9514) is classified as Class2
# Point x56 (value: 0.3085) is classified as Class1
# Point x57 (value: 0.4431) is classified as Class1
# Point x58 (value: 0.6489) is classified as Class2
# Point x59 (value: 0.5951) is classified as Class2
# Point x60 (value: 0.6494) is classified as Class2
# Point x61 (value: 0.8220) is classified as Class2
# Point x62 (value: 0.0037) is classified as Class1
# Point x63 (value: 0.3176) is classified as Class1
# Point x64 (value: 0.6001) is classified as Class2
# Point x65 (value: 0.0311) is classified as Class1
# Point x66 (value: 0.7752) is classified as Class2
# Point x67 (value: 0.0432) is classified as Class1
# Point x68 (value: 0.2458) is classified as Class1
# Point x69 (value: 0.1991) is classified as Class1
# Point x70 (value: 0.7356) is classified as Class2
# Point x71 (value: 0.6911) is classified as Class2
# Point x72 (value: 0.6281) is classified as Class2
# Point x73 (value: 0.4202) is classified as Class1
# Point x74 (value: 0.1846) is classified as Class1
# Point x75 (value: 0.0862) is classified as Class1
# Point x76 (value: 0.3362) is classified as Class1
# Point x77 (value: 0.4087) is classified as Class1
# Point x78 (value: 0.5370) is classified as Class2
# Point x79 (value: 0.1372) is classified as Class1
# Point x80 (value: 0.6984) is classified as Class2
# Point x81 (value: 0.2094) is classified as Class1
# Point x82 (value: 0.2957) is classified as Class1
# Point x83 (value: 0.7109) is classified as Class2
# Point x84 (value: 0.7044) is classified as Class2
# Point x85 (value: 0.9569) is classified as Class2
# Point x86 (value: 0.1506) is classified as Class1
# Point x87 (value: 0.3971) is classified as Class1
# Point x88 (value: 0.3868) is classified as Class1
# Point x89 (value: 0.1193) is classified as Class1
# Point x90 (value: 0.7730) is classified as Class2
# Point x91 (value: 0.0539) is classified as Class1
# Point x92 (value: 0.4980) is classified as Class2
# Point x93 (value: 0.7982) is classified as Class2
# Point x94 (value: 0.4786) is classified as Class1
# Point x95 (value: 0.7616) is classified as Class2
# Point x96 (value: 0.1538) is classified as Class1
# Point x97 (value: 0.3181) is classified as Class1
# Point x98 (value: 0.1875) is classified as Class1
# Point x99 (value: 0.0363) is classified as Class1
# Point x100 (value: 0.7601) is classified as Class2
#
#
# Classification complete.

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# Reduced dataset size
data = np.random.rand(40)
labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:20]]  # Adjusted for smaller training set

def euclidean_distance(x1, x2):
    return abs(x1 - x2)

def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]
    distances.sort(key=lambda x: x[0])
    k_nearest_neighbors = distances[:k]
    k_nearest_labels = [label for _, label in k_nearest_neighbors]
    return Counter(k_nearest_labels).most_common(1)[0][0]

train_data = data[:20]  # First 20 points for training
train_labels = labels
test_data = data[20:]  # Remaining 20 points for testing

# Reduced k values
k_values = [1, 2, 3, 4, 5, 20, 30]

print("--- k-Nearest Neighbors Classification ---")
print("Training dataset: First 20 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 20 points to be classified\n")

results = {}

for k in k_values:
    print(f"Results for k = {k}:")
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels
    for i, label in enumerate(classified_labels, start=21):
        print(f"Point x{i} (value: {test_data[i - 21]:.4f}) is classified as {label}")
    print("\n")

print("Classification complete.\n")

for k in k_values:
    classified_labels = results[k]
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]

    plt.figure(figsize=(10, 8))
    plt.scatter(train_data, [0] * len(train_data),
                c=["blue" if label == "Class1" else "red" for label in train_labels], label="Training Data", marker="o")
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")

    plt.title(f"k-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 20 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 20 points to be classified
#
# Results for k = 1:
# Point x21 (value: 0.8315) is classified as Class2
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class2
# Point x25 (value: 0.5941) is classified as Class2
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class2
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class2
# Point x30 (value: 0.7165) is classified as Class2
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class2
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class2
# Point x40 (value: 0.8244) is classified as Class2
#
#
# Results for k = 2:
# Point x21 (value: 0.8315) is classified as Class2
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class2
# Point x25 (value: 0.5941) is classified as Class2
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class2
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class2
# Point x30 (value: 0.7165) is classified as Class2
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class2
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class2
# Point x40 (value: 0.8244) is classified as Class2
#
#
# Results for k = 3:
# Point x21 (value: 0.8315) is classified as Class2
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class2
# Point x25 (value: 0.5941) is classified as Class2
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class2
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class2
# Point x30 (value: 0.7165) is classified as Class2
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class2
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class2
# Point x40 (value: 0.8244) is classified as Class2
#
#
# Results for k = 4:
# Point x21 (value: 0.8315) is classified as Class2
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class2
# Point x25 (value: 0.5941) is classified as Class2
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class2
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class2
# Point x30 (value: 0.7165) is classified as Class2
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class2
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class2
# Point x40 (value: 0.8244) is classified as Class2
#
#
# Results for k = 5:
# Point x21 (value: 0.8315) is classified as Class2
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class2
# Point x25 (value: 0.5941) is classified as Class2
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class2
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class2
# Point x30 (value: 0.7165) is classified as Class2
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class2
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class2
# Point x40 (value: 0.8244) is classified as Class2
#
#
# Results for k = 20:
# Point x21 (value: 0.8315) is classified as Class1
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class1
# Point x25 (value: 0.5941) is classified as Class1
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class1
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class1
# Point x30 (value: 0.7165) is classified as Class1
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class1
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class1
# Point x40 (value: 0.8244) is classified as Class1
#
#
# Results for k = 30:
# Point x21 (value: 0.8315) is classified as Class1
# Point x22 (value: 0.1174) is classified as Class1
# Point x23 (value: 0.3623) is classified as Class1
# Point x24 (value: 0.6044) is classified as Class1
# Point x25 (value: 0.5941) is classified as Class1
# Point x26 (value: 0.1526) is classified as Class1
# Point x27 (value: 0.5545) is classified as Class1
# Point x28 (value: 0.3305) is classified as Class1
# Point x29 (value: 0.9996) is classified as Class1
# Point x30 (value: 0.7165) is classified as Class1
# Point x31 (value: 0.3344) is classified as Class1
# Point x32 (value: 0.0745) is classified as Class1
# Point x33 (value: 0.2367) is classified as Class1
# Point x34 (value: 0.3363) is classified as Class1
# Point x35 (value: 0.4767) is classified as Class1
# Point x36 (value: 0.2431) is classified as Class1
# Point x37 (value: 0.6983) is classified as Class1
# Point x38 (value: 0.0640) is classified as Class1
# Point x39 (value: 0.7519) is classified as Class1
# Point x40 (value: 0.8244) is classified as Class1
#
#
# Classification complete.
